# %%
# !wget https://github.com/bekou/multihead_joint_entity_relation_extraction/archive/master.zip
# Out:
# --2019-07-21 13:08:34--  https://github.com/bekou/multihead_joint_entity_relation_extraction/archive/master.zip
# Resolving github.com (github.com)... 192.30.253.112
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/bekou/multihead_joint_entity_relation_extraction/zip/master [following]
# --2019-07-21 13:08:34--  https://codeload.github.com/bekou/multihead_joint_entity_relation_extraction/zip/master
# Resolving codeload.github.com (codeload.github.com)... 192.30.253.121
# Connecting to codeload.github.com (codeload.github.com)|192.30.253.121|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [             <=>    ] 171.24M  24.3MB/s    in 9.6s
#
# 2019-07-21 13:08:44 (17.8 MB/s) - ‘master.zip’ saved [179562931]

# %%
# !unzip master.zip
# Out:
# Archive:  master.zip
# 9fcabf5d940838f764e611728e03597be487d43f
#    creating: multihead_joint_entity_relation_extraction-master/
#   inflating: multihead_joint_entity_relation_extraction-master/.gitignore
#   inflating: multihead_joint_entity_relation_extraction-master/README.md
#   inflating: multihead_joint_entity_relation_extraction-master/build_data.py
#    creating: multihead_joint_entity_relation_extraction-master/configs/
#    creating: multihead_joint_entity_relation_extraction-master/configs/CoNLL04/
#   inflating: multihead_joint_entity_relation_extraction-master/configs/CoNLL04/bio_config
#   inflating: multihead_joint_entity_relation_extraction-master/configs/CoNLL04/bio_config_adv
#   inflating: multihead_joint_entity_relation_extraction-master/configs/CoNLL04/ec_config
#   inflating: multihead_joint_entity_relation_extraction-master/configs/CoNLL04/ec_config_adv
#    creating: multihead_joint_entity_relation_extraction-master/configs/DREC/
# ...

# %%
# !ls
# Out:
# download_data.sh				   pennchar
# master.zip					   sample_data
# multihead_joint_entity_relation_extraction-master  simple-examples.tgz
# penn

# %%
# %cd multihead_joint_entity_relation_extraction-master
# Out:
# /content/multihead_joint_entity_relation_extraction-master

# %%
# !ls
# Out:
# build_data.py  data	parsers.py  run.sh	 train_es.py	utils.py
# configs        eval.py	README.md   tf_utils.py  train_eval.py

# %%
# !sh ./run.sh
# Out:
# Archive:  data/CoNLL04/vecs.lc.over100freq.zip
#   inflating: data/CoNLL04/vecs.lc.over100freq.txt
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# /content/multihead_joint_entity_relation_extraction-master/parsers.py:68: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   engine='python', sep="\t", quoting=csv.QUOTE_NONE).as_matrix()
# ...
